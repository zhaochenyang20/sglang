# %%
# !pip install sglang[all]
# Out:
# WARNING: Ignoring invalid distribution ~ransformers (/home/chenyang/miniconda3/envs/AlphaMeemory/lib/python3.11/site-packages)
# ...
# WARNING: Ignoring invalid distribution ~ransformers (/home/chenyang/miniconda3/envs/AlphaMeemory/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/home/chenyang/miniconda3/envs/AlphaMeemory/lib/python3.11/site-packages)
